# %%
# !pip install ultralytics
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
from ultralytics import YOLO
weights_loc = "/Users/taylor/runs/detect/train14/weights/best.pt"
model_2 = YOLO(weights_loc)
results = model_2.predict(source="0", show=True)
# Out:
# 1/1: 0... Success ✅ (inf frames of shape 1920x1080 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 1 yourleft, 117.5ms
# 0: 384x640 1 yourleft, 104.1ms
# 0: 384x640 1 yourleft, 105.7ms
# 0: 384x640 1 yourleft, 107.3ms
# 0: 384x640 1 yourleft, 100.1ms
# 0: 384x640 1 yourleft, 101.4ms
# 0: 384x640 1 myright, 1 yourleft, 102.5ms
# 0: 384x640 1 yourleft, 99.3ms
# 0: 384x640 1 myright, 101.5ms
# 0: 384x640 1 myright, 1 yourleft, 101.9ms
# ...
